# %% [markdown]
# # Marketing Analytics - Actividad No. 1
# ## Configuracion Inicial (Google Colab)
#
# Repositorio: https://github.com/PikaGuty/marketing-analytics-javier-gutierrez

# %% [markdown]
# ### 1. Conectar Colab con el repositorio de GitHub

# %%
# 1. Trae tu repositorio a Colab
# !git clone https://github.com/PikaGuty/marketing-analytics-javier-gutierrez.git

# %%
# 2. Entra a la carpeta de esta semana
# %cd marketing-analytics-javier-gutierrez/Semana_1

# %%
# 3. Instala las dependencias
# !pip install -r requirements.txt

# %% [markdown]
# ### 2. Entrenamiento del modelo predictivo (Regresion Lineal)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

variable_x = np.array([[10], [20], [30], [40],[50]])
variable_y = np.array([15,25,35,45,55])

modelo_lr = LinearRegression()
modelo_lr.fit(variable_x,variable_y)

gasto = 100

resultado = modelo_lr.predict([[gasto]])
print(f"Las ventas proyectadas para una inversion de ${gasto} son: ${resultado[0]}")
